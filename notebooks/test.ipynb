# %%
import pandas as pd

# %%
from cibmtr.test import random_matrix

random_matrix(10)
# Out:
# array([[0.51448853, 0.11561183, 0.52481752, 0.95451779, 0.870239  ,
#         0.55320176, 0.77936512, 0.65326722, 0.85642553, 0.54099709],
#        [0.6322871 , 0.68567723, 0.15154786, 0.09680769, 0.83226924,
#         0.21465881, 0.05365324, 0.53020753, 0.98237021, 0.61840473],
#        [0.35708055, 0.12866   , 0.4917395 , 0.87699005, 0.28103334,
#         0.88375029, 0.88245224, 0.29197536, 0.07353612, 0.76869029],
#        [0.12449129, 0.21059323, 0.01800467, 0.88984491, 0.91830279,
#         0.05590128, 0.37258731, 0.95474967, 0.3172534 , 0.70286742],
#        [0.51189921, 0.29098163, 0.20021293, 0.86013491, 0.01015978,
#         0.19542206, 0.50021554, 0.11189363, 0.60055139, 0.90814796],
#        [0.02665859, 0.31228862, 0.99900753, 0.51048103, 0.19549115,
#         0.68141966, 0.53775917, 0.12656162, 0.20898757, 0.77971982],
#        [0.46299983, 0.29139241, 0.31754151, 0.99293943, 0.10608767,
#         0.41554368, 0.54917535, 0.31159555, 0.76354998, 0.52358218],
# ...

# %%
import torch

t = torch.randn(10, 10)

t.cuda()
# Out:
# tensor([[ 1.4001,  0.9803,  2.5616,  0.5164, -0.0612,  1.3473, -0.5845, -0.3279,
#          -1.1734, -1.1220],
#         [-0.1374, -2.9061, -0.1942,  0.4679,  1.6505, -0.1846, -0.1094, -0.3811,
#          -1.4428,  0.8932],
#         [-1.5159,  1.3783,  0.9184,  0.2395, -0.3940,  0.2391,  0.1766,  1.3172,
#          -0.1329, -1.0954],
#         [-0.9327, -0.9617, -0.4464, -1.2317, -0.4057, -0.5241,  0.8134, -0.9304,
#          -1.7712,  0.4367],
#         [ 1.4176, -0.0330,  1.3736, -1.0753,  0.4599, -0.3111, -1.5524,  1.3434,
#          -0.2113, -0.6305],
#         [ 1.6562,  0.5505, -0.1161, -1.8433,  0.5045,  0.0137,  0.7408, -0.1749,
#          -0.0849, -0.4240],
#         [ 0.4155,  2.2717,  0.2536, -2.0235,  1.3805,  1.0348, -0.2962, -0.5486,
#           0.0074,  0.5859],
#         [-1.5638, -0.6770,  1.4901, -0.5567,  0.3361,  0.7889,  1.0960, -1.5592,
#          -0.0526,  0.0894],
#         [-1.1438, -2.8023, -0.3983, -1.5512, -1.5177, -0.1314, -1.4863,  1.0665,
# ...
